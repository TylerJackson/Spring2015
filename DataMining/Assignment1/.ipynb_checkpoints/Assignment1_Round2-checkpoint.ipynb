# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### by Tyler Jackson

# %% [markdown]
# ###     Business Understanding

# %% [markdown]
# This data was originally gathered by the US Census Bureau in 1994.  It was then extracted by Barry Becker in 1996, based on a few different characteristics.  In order for him to accept the data a record needed to satisfy these constraints were: the age of the person was greater than 16, their annual gross income had to be greater than $100, their hours worked/week had to be greater than 0, and the final weight had to be greater than 1.
#
# The main goal of his analysis was to create an algorithm that could predict whether or not someone's income was more than $50,000 a year.  The way he determined the success of his different algorithms was by testing his model against a test dataset and calculating how often his algorithms returned the correct prediction (greater than $50k annual gross income or less than 50K annual gross income) in relation to what their actual reported annual gross income was.  Most of his algorithms had approximately 15% error, meaning that 85% of the time his algorithm made a correct prediction on their annual gross income being greater or less than $50,000.
#
# The number of instances he used was 48,842.  The amount used to create his model was 32,561 and the amount he tested against was 16,281.  Although the Census Bureau does provide a final weight for each record, this seems like a very small sample size to be used as a representation for the population.  The data has 14 attributes and 1 binomial label, meaning 14 were used to build the model for his prediction.  85% seems like a low success rate, but depending on what one is using it for, this might be considered acceptable.  For example, lets say I was trying to target individuals who had an annual gross income of more than $50K to sell a really expensive product I was creating.  Being able to send out advertisements to my target market with an 85% success rate seems sufficient in this case.

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# ##### Attributes

# %% [markdown]
#     As mentioned above, there are 14 different attributes in the data set with 1 binomial label.  The first attribute is Age which refers to the age of the person and ranges from 17 to 90 years.  Age is a continuous ratio data type because you can add ages, multiply ages, they are distinct, and their order matters.
#
#     The second attribute is Work_Class which refers to the type of work the record does.  The various values of the Work_Class attribute are Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, and Never-worked.  This attribute's data type is discrete and nominal, because these values are categories in which the order does not matter.  Self-emp-not-inc refers to the self employed person who has not incorporated, and Self-emp-inc is someone who is self-employed and incorporated.  Without pay is someone who works without pay, and Never-Worked refers to someone who has never worked.  We will group Self-emp-not-inc, and Self-emp-inc into one category called Self-Employed.  We will group the Federal-gov, State-gov, and Local-gov into a category called Government-Worker.  The Without-pay and Never-worked categories will be grouped into a Not-Paid category.
#
#     The third attribute is Final_Weight.  Final_Weight is an attribute that is provided by the US Census Bureau and refers to how much of the population the individual record represents.  It is used to account for sampling error.  For example, if the sample was not indicative of the population the data wouldn't be very useful.  The Final_Weight is designed to counteract errors that result from either sampling one demographic too often, or from another demographic not returning the survey quite as often.  For example, if the survey was only passed out online, then it would be biased towards people who could afford a computer, and those with lower income would be underrepresented.  The Final_Weight is a continuous ratio because the values can be multiplied and added to each other, their order matters, and they are distinct.
#
#     Educ is the next attribute and refers to the completed education level of the record.  Educ is ordinal and discrete, because the order does matter, and it is categorical.  The possible values for Educ are Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, and Preschool.  In order to  simplify the dataset into more understandable groups we will group Educ into 'Didnt_Finish_HS','HS_Grad','College_Degree', 'Masters', and 'Doctorate'.  This will group everyone with some college but no degree into HS_Grad as that would be their highest completed education.
#
#     Educ_Num is the numerical representation of Educ.  The UCI Machine Learning Repository says it is a continuous datatype, but I disagree.  It is ordinal and discrete with integer values ranging from 1 to 16.  The order matters, because a higher value implies there is more education.  It is not continuous, because an Educ_Num value twice as high as another doesn't directly correlate to twice as much education.  Also, there are no fractional values which a continuous variable implies there could be.  We will discard this attribute, because the Educ attribute provides enough detail for the scope of our analysis.
#
#     Marital_Status is a nominal discrete attribute with values such as Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, and Married-AF-spouse.  These values are categorical, and order does not matter.  The three marriage options are married with a civilian as your spouse, married with your spouse absent, and married with your spouse in the Armed Forces, but we will group all three of these into a Married category.  We will also group Divorced and Separated together into a Divorced category.
#
#     Occupation refers to the type of job the record held.  It is also nominal and discrete as the order doesn't matter and the options are categories.  The possible values are Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, and Armed-Forces.  Machine-op-inspct refers to a machine operator or inspector.  We will group these categories into Upper-Management(Exec-managerial), Manual-Labor(Machine-op-inspct,Transport-moving,Farming-fishing), Military(Protective-serv, Armed Forces),Specialty-Services(Prof-specialty,Tech-support,Craft-repair),Sales, and Other-service(Handlers-cleaners,Other-service,Adm-clerical,Priv-house-serv).
#
#     The Relationship attribute is categorical and nominal and refers to more familial relationships.  The obscure aspect of this attribute is that there is only one relationship per record.  My guess is that the survey asked for the defining relationship, or the most significant relationship.  The possible values for this attribute are Wife, Own-child, Husband, Not-in-family, Other-relative, and Unmarried. This attribute will also be removed as it is not very useful.
#
#     The Race attribute is nominal and discrete, and its possible values are White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.  There is no order and these are categorical values.
#
#     The Sex attribute is binomial and will be changed to 'Is_Male', with Male values corresponding to 1 and Female values corresponding to 0.  It is nominal and discrete as there are two categories in which order does not matter.
#
#     Cap_Gain and Cap_Loss are two continuous ratio data types.  They refer to the money one made and loss on selling captial assets meaning investments in stock, bonds, etc.  If someone sold their asset for more than they purchased it then the difference is a Capital Gain.  Cap_Gain values range from $0 to $99,999 and Cap_Loss ranges from $0 to $4356.  Both of these attributes are going to be removed because only 2700 records have Cap_Gain values greater than $0 and only 1500 records have Cap_Loss values greater than $0.
#
#     The Hrs_Per_Week attribute is a continuous ratio data type.  The values are distinct, order matters, they can be added to each other and multiplied.  The values range from 1 hour to 99 hours per week.
#
#     Nat_Country refers to the person's native country, and is nominal and discrete.  The values are categorical, and order does not matter.  The possible values for this category are United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, and Holand-Netherlands.  This column will be changed to is_US_Native, with a 1 corresponding to the records where Nat_Country is the United-States, and 0 when it is not.  I thought about maybe grouping it by continent, but thought that might be misleading as the financial situations of countries can vary so greatly within a continent.  I also thought it would be a cool attribute to be able to compare against whether or not the person was originally from the U.S.
#
#     The last column refers to the binomial label Is_Grtr_50 which is what the original data analysis was trying to be modeled to predict.  This column will be changed to have 1 correspond to >50K and 0 corresponding to <=50K.
#
#     The data also has missing values, so we will replace the missing values with the mean for the continuous data.  The rows with missing values in the categorical data will be removed.  Originally, I had planned on replacing them with the mode as the mode is already the most occuring value.  I decided not to because I didn't want the mode to become inflated by speculating the likelihood of those missing values being consistent with the rest of the data.

# %%
import pandas as pd
import mpld3

#load in the data to the data frame
df = pd.read_csv("./dataset_Census_Income/adult.data")

#This will give you some more general information about the columns and then 
#show the first 5 rows so that the original data can be seen before being modified.
print df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# Age               32561 non-null int64
# Work_Class        32561 non-null object
# Final_Weight      32561 non-null int64
# Educ              32561 non-null object
# Educ_Num          32561 non-null int64
# Marital_Status    32561 non-null object
# Occupation        32561 non-null object
# Relationship      32561 non-null object
# Race              32561 non-null object
# Sex               32561 non-null object
# Cap_Gain          32561 non-null int64
# Cap_Loss          32561 non-null int64
# Hrs_Per_Week      32561 non-null int64
# Nat_Country       32561 non-null object
# Is_Grtr_50        32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB
# None
#    Age        Work_Class  Final_Weight       Educ  Educ_Num  \
# 0   39         State-gov         77516  Bachelors        13
# 1   50  Self-emp-not-inc         83311  Bachelors        13
# ...

# %%
#delete the columns we aren't using and change names to be clearer
del df['Educ_Num']
del df['Relationship']
del df['Cap_Gain']
del df['Cap_Loss']

#as mentioned above rename Sex to IsMale
df['Is_Male'] = df['Sex']
del df['Sex']

#rename Nat_Country to Is_US_Native
df['Is_US_Native'] = df['Nat_Country']
del df['Nat_Country']

#group the categorical attributes so that we can view statitics on them (normally the continuous data trumps the categorical)
categ_features = ['Is_Male','Is_Grtr_50','Work_Class','Occupation','Marital_Status','Educ','Race','Is_US_Native']
df_categs = df[categ_features]

df_categs.describe()
#On first glance you would think there are no missing values, but that is because the missing values are represented by ? marks
# Out:
#        Is_Male Is_Grtr_50 Work_Class      Occupation      Marital_Status  \
# count    32561      32561      32561           32561               32561
# unique       2          2          9              15                   7
# top       Male      <=50K    Private  Prof-specialty  Married-civ-spouse
# freq     21790      24720      22696            4140               14976
#
#            Educ   Race   Is_US_Native
# count     32561  32561          32561
# unique       16      5             42
# top     HS-grad  White  United-States
# freq      10501  27816          29170

# %%
#replace any missing data values with numpy's Not a Number
#this way when we call describe we can see how many missing values there are in each attribute
import numpy as np
df = df.replace(to_replace= '?', value =np.nan)

df_categs = df[categ_features]

df_categs.describe()

#As you can see, a lot of these attributes have many unique values.  We will group the Work_Class, Occupation, Marital_Status, Educ,
# and Nat_Country into broader categories so that there are fewer unique values for each.  There are also some missing values
#that are represented by NaN.  The aggregates ignore NaN.
# Out:
#        Is_Male Is_Grtr_50 Work_Class      Occupation      Marital_Status  \
# count    32561      32561      30725           30718               32561
# unique       2          2          8              14                   7
# top       Male      <=50K    Private  Prof-specialty  Married-civ-spouse
# freq     21790      24720      22696            4140               14976
#
#            Educ   Race   Is_US_Native
# count     32561  32561          31978
# unique       16      5             41
# top     HS-grad  White  United-States
# freq      10501  27816          29170

# %%
#Grouping the categories better.

#group the work class attribute into fewer categories as mentioned above.
df = df.replace(to_replace=['Self-emp-inc','Self-emp-not-inc'],value=['Self-Employed','Self-Employed'])
df = df.replace(to_replace=['Federal-gov','Local-gov','State-gov'],value=['Government-Worker','Government-Worker','Government-Worker'])
df = df.replace(to_replace=['Without-pay','Never-worked'],value=['Not-Paid','Not-Paid'])

#group the occupation options into their categories mentioned above
df = df.replace(to_replace=['Exec-managerial'], value=['Upper-Management'])
df = df.replace(to_replace=['Machine-op-inspct','Transport-moving','Farming-fishing'],value=['Manual-Labor','Manual-Labor','Manual-Labor'])
df = df.replace(to_replace=['Protective-serv','Armed-Forces'],value=['Military','Military'])
df = df.replace(to_replace=['Prof-specialty','Tech-support','Craft-repair'],value=['Specialty-Service','Specialty-Service','Specialty-Service'])
df = df.replace(to_replace=['Handlers-cleaners','Other-service','Adm-clerical','Priv-house-serv'],value=['Other-service','Other-service','Other-service','Other-service'])

#group the marital status attribute into fewer categories as mentioned above.
df = df.replace(to_replace=['Married-civ-spouse','Married-AF-spouse','Married-spouse-absent'],value=['Married','Married','Married'])
df = df.replace(to_replace='Separated',value='Divorced')

#group the various educational groups into the categories mentioned above
df = df.replace(to_replace=['Bachelors','Prof-school','Assoc-acdm','Assoc-voc'],value=['College_Degree','College_Degree','College_Degree','College_Degree'])
df = df.replace(to_replace='Some-college',value='HS-grad')
df = df.replace(to_replace=['11th','9th','7th-8th','12th','1st-4th','10th','5th-6th','Preschool'],value=['No_HS_Diploma','No_HS_Diploma','No_HS_Diploma','No_HS_Diploma','No_HS_Diploma','No_HS_Diploma','No_HS_Diploma','No_HS_Diploma'])

#change Nat_Country to is US or isn't US native
bad_countries = ['Cambodia', 'England', 'Puerto-Rico', 'Canada', 'Germany', 'Outlying-US(Guam-USVI-etc)', 'India', 'Japan', 'Greece', 'South', 'China', 'Cuba', 'Iran', 'Honduras', 'Philippines', 'Italy', 'Poland', 'Jamaica', 'Vietnam', 'Mexico', 'Portugal', 'Ireland', 'France', 'Dominican-Republic', 'Laos', 'Ecuador', 'Taiwan', 'Haiti', 'Columbia', 'Hungary', 'Guatemala', 'Nicaragua', 'Scotland', 'Thailand', 'Yugoslavia', 'El-Salvador', 'Trinadad&Tobago', 'Peru', 'Hong','Holand-Netherlands']
df = df.replace(to_replace=bad_countries,value=['Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US','Not-US'])

# %%
#clean up the columns to be 0 and 1 for the binomial data
df = df.replace(to_replace=['>50K','<=50K'], value=[1,0])
df = df.replace(to_replace=['Male','Female'], value=[1,0])
df = df.replace(to_replace=['United-States','Not-US'],value=[1,0])

#make sure that the continuous attributes are treated as such, and that the numerical categorical attributes 
#are treated as categories
numeric_features = ['Age','Final_Weight','Hrs_Per_Week']
for feat in numeric_features:
    df[feat] = df[feat].values.astype(np.float)

#I added this feature for the age range so that I could group by their age as another form of analysis.
df['Age_Range'] = pd.cut(df.Age,[0,30,60,1e6],3,labels=['Early Adulthood','Adult','Senior'])

# %%
categ_features = ['Is_Male','Is_Grtr_50','Work_Class','Occupation','Marital_Status','Educ','Race','Is_US_Native','Age_Range']
df_categs = df[categ_features]

categ_features_make_categ = ['Is_Male','Is_Grtr_50','Is_US_Native']
for feat in categ_features_make_categ:
    df_categs[feat] = pd.Categorical(df_categs[feat].values.astype(np.float))

df_categs.describe()

#As you can see there are now much fewer unique values, but we still have missing values
# Out:
#         Is_Male  Is_Grtr_50 Work_Class         Occupation Marital_Status  \
# count     32561       32561      30725              30718          32561
# unique        2           2          4                  6              4
# top           1           0    Private  Specialty-Service        Married
# freq      21790       24720      22696               9167          15417
#
#            Educ   Race  Is_US_Native Age_Range
# count     32561  32561         31978     32561
# unique        5      5             2         3
# top     HS-grad  White             1     Adult
# freq      17792  27816         29170     19657

# %%
#I included the way that I was going to impute the mode, just in case I changed my mind at somepoint and wanted to do
#that, I could.
#categ_features_to_impute = ['Work_Class','Occupation','Is_US_Native']
#for feat in categ_features_to_impute:
#    df[feat] = df[feat].replace(to_replace= np.nan, value =df[feat].describe().top)
    #This had to be called again b.c. the imputing removed the categorical flag
#df['Is_US_Native'] = pd.Categorical(df['Is_US_Native'].values.astype(np.float))

# %%
#Before dropping the rows with missing values we want to impute the mean into the missing values for the continuous data
#First lets see how many missing values we had
df.describe()
#As you can see by looking at the count there are no missing values.
#The average age is 38 years old, the average weight is 189,778, and the average hours per week is 40.  The average weight
#means that on average each row represents about 189,778 people in the population.  You can see the range for each of these
#values is extremely high.  The fact that the standard deviation is small in relation compared to the range implies there are
#probably some outliers in the data.
# Out:
#                 Age    Final_Weight  Hrs_Per_Week    Is_Grtr_50       Is_Male  \
# count  32561.000000    32561.000000  32561.000000  32561.000000  32561.000000
# mean      38.581647   189778.366512     40.437456      0.240810      0.669205
# std       13.640433   105549.977697     12.347429      0.427581      0.470506
# min       17.000000    12285.000000      1.000000      0.000000      0.000000
# 25%       28.000000   117827.000000     40.000000      0.000000      0.000000
# 50%       37.000000   178356.000000     40.000000      0.000000      1.000000
# 75%       48.000000   237051.000000     45.000000      0.000000      1.000000
# max       90.000000  1484705.000000     99.000000      1.000000      1.000000
#
#        Is_US_Native
# count  31978.000000
# mean       0.912190
# std        0.283023
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
#drop rows with missing values
df = df.dropna()
categ_features = ['Is_Male','Is_Grtr_50','Work_Class','Occupation','Marital_Status','Educ','Race','Is_US_Native']
df_categs = df[categ_features]

#categ_features_make_categ = ['Is_Male','Is_Grtr_50','Is_US_Native']
#for feat in categ_features_make_categ:
#    df_categs[feat] = pd.Categorical(df_categs[feat].values.astype(np.float))
df_categs.describe()

#Now you can see that we have no missing values, and all the attributes have the same count (number of rows).  You can see
#that in the sample, the most common values were men, people making less than 50K a year, Private workers, people providing
#Other Services, Married people, people with High-School as their highest Education, White people, and people born in the 
#United States.
# Out:
#             Is_Male    Is_Grtr_50  Is_US_Native
# count  30162.000000  30162.000000  30162.000000
# mean       0.675685      0.248922      0.911876
# std        0.468126      0.432396      0.283480
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      1.000000
# 50%        1.000000      0.000000      1.000000
# 75%        1.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000

# %%
#Now let's do some groupings and find some classifiers

#For each of these groupings I will display the sample data as well
#as the adjusted data when the final weight is taken into account

#I will also define a pop rate for each grouping that will represent
#the average each value in the group making more than $50K a year.
#This value will be used for our visualizations later

df_grouped1 = df.groupby(by='Marital_Status')  

df_grouped1_pop_rate = df[df.Is_Grtr_50==1].groupby(by='Marital_Status').Final_Weight.sum() / df_grouped1.Final_Weight.sum()
print "Averages based on Marital Status"
print
print df_grouped1.Is_Grtr_50.sum()
print '------------------------'
print df_grouped1.Is_Grtr_50.count()
print '------------------------'
print df_grouped1.Is_Grtr_50.sum() / df_grouped1.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by='Marital_Status').Final_Weight.sum()
print '------------------------'
print df_grouped1.Final_Weight.sum()
print '------------------------'
print df_grouped1_pop_rate


#This will show the averages of each group making more than $50K/yr based on a person's marital status.
#This is a really cool metric because we can see that you are 
#most likely to be making more than $50K a year if you are married by far.
# Out:
# Averages based on Marital Status
#
# Marital_Status
# Divorced           518
# Married           6440
# Never-married      470
# Widowed             80
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Marital_Status
# Divorced           5153
# Married           14456
# Never-married      9726
# Widowed             827
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Marital_Status
# Divorced          0.100524
# Married           0.445490
# Never-married     0.048324
# Widowed           0.096735
# Name: Is_Grtr_50, dtype: float64
#
# Compared to Average with Final Weight Accounted For
# Marital_Status
# Divorced            97377795
# Married           1209311401
# Never-married       93292200
# Widowed             12648520
# Name: Final_Weight, dtype: float64
# ------------------------
# Marital_Status
# Divorced           977186314
# Married           2698952481
# Never-married     1903405235
# Widowed            145017589
# ...

# %%
df_grouped2 = df.groupby(by=['Marital_Status','Is_US_Native'])  

df_grouped2_pop_rate = df[df.Is_Grtr_50==1].groupby(by=['Marital_Status','Is_US_Native']).Final_Weight.sum() / df_grouped2.Final_Weight.sum()

print "Averages based on Marital Status and if you are a U.S. Native"
print
print df_grouped2.Is_Grtr_50.sum()
print '------------------------'
print df_grouped2.Is_Grtr_50.count()
print '------------------------'
print df_grouped2.Is_Grtr_50.sum() / df_grouped2.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by=['Marital_Status','Is_US_Native']).Final_Weight.sum()
print '------------------------'
print df_grouped2.Final_Weight.sum()
print '------------------------'
print df_grouped2_pop_rate

#This is cool because you can see the likelihood of each attribute based on your marital status and
#if you were born in the U.S.  We can see that out of these groups, if you are married and from the U.S. originally you have
#the greatest chance of making over $50K a year.  This is also cool because we can see that in all cases except for Widowed,
#your odds of making more than $50K increase if you are from the U.S.
# Out:
# Averages based on Marital Status and if you are a U.S. Native
#
# Marital_Status  Is_US_Native
# Divorced        0                 29
#                 1                489
# Married         0                446
#                 1               5994
# Never-married   0                 29
#                 1                441
# Widowed         0                  9
#                 1                 71
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Marital_Status  Is_US_Native
# Divorced        0                 335
#                 1                4818
# Married         0                1404
#                 1               13052
# Never-married   0                 850
#                 1                8876
# Widowed         0                  69
#                 1                 758
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Marital_Status  Is_US_Native
# Divorced        0               0.086567
#                 1               0.101494
# ...

# %%
df_grouped3 = df.groupby(by='Educ')

df_grouped3_pop_rate = df[df.Is_Grtr_50==1].groupby(by='Educ').Final_Weight.sum() / df_grouped3.Final_Weight.sum()

print df_grouped3.Is_Grtr_50.sum()
print '------------------------'
print df_grouped3.Is_Grtr_50.count()
print '------------------------'
print df_grouped3.Is_Grtr_50.sum() / df_grouped3.Is_Grtr_50.count()
print
print "Compared tp Above with Final_Weight Accounted For"
print
print df[df.Is_Grtr_50==1].groupby(by='Educ').Final_Weight.sum()
print '------------------------'
print df_grouped3.Final_Weight.sum()
print '------------------------'
print df_grouped3_pop_rate

#This metric shows the odds of each educational category making more than $50K a year.  So if you have a doctorate you have 
#74.6% change of making more than $50K a year.  We can also see the value of getting a college degree by comparing the odds
#of making more than $50K with a college degree vs. just with a HS diploma.  The odds more than double that you will make more 
#than $50K a year if you get a college degree.  We can also see that without graduating High School you have almost no chance
#of making more than $50K a year, but it is still not impossible.
# Out:
# Educ
# College_Degree    3132
# Doctorate          280
# HS-grad           2953
# Masters            918
# No_HS_Diploma      225
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Educ
# College_Degree     7901
# Doctorate           375
# HS-grad           16518
# Masters            1627
# No_HS_Diploma      3741
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Educ
# College_Degree    0.396406
# Doctorate         0.746667
# HS-grad           0.178775
# Masters           0.564229
# No_HS_Diploma     0.060144
# Name: Is_Grtr_50, dtype: float64
#
# Compared tp Above with Final_Weight Accounted For
#
# Educ
# College_Degree    589764423
# Doctorate          54109990
# HS-grad           560668963
# Masters           166580199
# No_HS_Diploma      41506341
# Name: Final_Weight, dtype: float64
# ------------------------
# Educ
# College_Degree    1479652502
# Doctorate           70793313
# HS-grad           3126620013
# Masters            292846214
# ...

# %%
#Next, we can compare the odds of making more than $50K based on if you are from the U.S. or not, and your Education.

df_grouped4 = df.groupby(by=['Educ','Is_US_Native'])  
df_grouped4_pop_rate = df[df.Is_Grtr_50==1].groupby(by=['Educ','Is_US_Native']).Final_Weight.sum() / df_grouped4.Final_Weight.sum()


print "Averages based on Education and if you are a U.S. Native"
print
print df_grouped4.Is_Grtr_50.sum()
print '------------------------'
print df_grouped4.Is_Grtr_50.count()
print '------------------------'
print df_grouped4.Is_Grtr_50.sum() / df_grouped4.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by=['Educ','Is_US_Native']).Final_Weight.sum()
print '------------------------'
print df_grouped4.Final_Weight.sum()
print '------------------------'
print df_grouped4_pop_rate



#You can see clearly that your odds of making more than $50K a year increase as you gain more education, and 
#increase again if you are from the U.S.
# Out:
# Averages based on Education and if you are a U.S. Native
#
# Educ            Is_US_Native
# College_Degree  0                226
#                 1               2906
# Doctorate       0                 41
#                 1                239
# HS-grad         0                145
#                 1               2808
# Masters         0                 69
#                 1                849
# No_HS_Diploma   0                 32
#                 1                193
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Educ            Is_US_Native
# College_Degree  0                 623
#                 1                7278
# Doctorate       0                  61
#                 1                 314
# HS-grad         0                1049
#                 1               15469
# Masters         0                 143
#                 1                1484
# No_HS_Diploma   0                 782
#                 1                2959
# ...

# %%
#Next, we can compare your race to the odds of making $50K a year

df_grouped5 = df.groupby(by='Race')  
df_grouped5_pop_rate = df[df.Is_Grtr_50==1].groupby(by='Race').Final_Weight.sum() / df_grouped5.Final_Weight.sum()

print "Averages based on Race"
print
print df_grouped5.Is_Grtr_50.sum()
print '------------------------'
print df_grouped5.Is_Grtr_50.count()
print '------------------------'
print df_grouped5.Is_Grtr_50.sum() / df_grouped5.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by='Race').Final_Weight.sum()
print '------------------------'
print df_grouped5.Final_Weight.sum()
print '------------------------'
print df_grouped5_pop_rate
# Out:
# Averages based on Race
#
# Race
# Amer-Indian-Eskimo      34
# Asian-Pac-Islander     248
# Black                  366
# Other                   21
# White                 6839
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Race
# Amer-Indian-Eskimo      286
# Asian-Pac-Islander      895
# Black                  2817
# Other                   231
# White                 25933
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Race
# Amer-Indian-Eskimo    0.118881
# Asian-Pac-Islander    0.277095
# Black                 0.129925
# Other                 0.090909
# White                 0.263718
# Name: Is_Grtr_50, dtype: float64
#
# Compared to Average with Final Weight Accounted For
# Race
# Amer-Indian-Eskimo       4475339
# Asian-Pac-Islander      40681907
# Black                   87611245
# Other                    4198360
# White                 1275663065
# Name: Final_Weight, dtype: float64
# ------------------------
# Race
# ...

# %%
#Next, let's compare the odds of making more than $50K a year with your race and your education

df_grouped6 = df.groupby(by=['Race','Educ'])  
df_grouped6_pop_rate = df[df.Is_Grtr_50==1].groupby(by=['Race','Educ']).Final_Weight.sum() / df_grouped6.Final_Weight.sum()

print "Averages based on Race and Education"
print
print df_grouped6.Is_Grtr_50.sum()
print '------------------------'
print df_grouped6.Is_Grtr_50.count()
print '------------------------'
print df_grouped6.Is_Grtr_50.sum() / df_grouped6.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by=['Race','Educ']).Final_Weight.sum()
print '------------------------'
print df_grouped6.Final_Weight.sum()
print '------------------------'
print df_grouped6_pop_rate

#As you can see, the two categories with the highest chance of making more than $50K per year are Other with a Doctorate, and 
#Black with a Doctorate.  Other isn't super ueeful, as that person is the only record in that group so regardless of the 
#weight, they end up representing the whole population for that group.  We can also see that without a HS diploma you have 
#almost no chance of making more than $50K per year regardless of Race or Education.  If you are black then your odds of 
#making more than $50K a year more than double if you get a Doctorate vs. just getting your Masters.  This grouping won't be 
#displayed in a bar graph as there are so many groups.
# Out:
# Averages based on Race and Education
#
# Race                Educ
# Amer-Indian-Eskimo  College_Degree      11
#                     Doctorate            1
#                     HS-grad             17
#                     Masters              3
#                     No_HS_Diploma        2
# Asian-Pac-Islander  College_Degree     125
#                     Doctorate           17
#                     HS-grad             58
#                     Masters             41
#                     No_HS_Diploma        7
# Black               College_Degree     130
#                     Doctorate            7
#                     HS-grad            170
#                     Masters             37
#                     No_HS_Diploma       22
# Other               College_Degree       8
#                     Doctorate            1
#                     HS-grad              8
#                     Masters              2
#                     No_HS_Diploma        2
# ...

# %%
#Next we can compare your occupation to the odds of making $50K a year

df_grouped7 = df.groupby(by='Occupation')  
df_grouped7_pop_rate = df[df.Is_Grtr_50==1].groupby(by='Occupation').Final_Weight.sum() / df_grouped7.Final_Weight.sum()

print "Averages based on Occupation"
print
print df_grouped7.Is_Grtr_50.sum()
print '------------------------'
print df_grouped7.Is_Grtr_50.count()
print '------------------------'
print df_grouped7.Is_Grtr_50.sum() / df_grouped7.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by='Occupation').Final_Weight.sum()
print '------------------------'
print df_grouped7.Final_Weight.sum()
print '------------------------'
print df_grouped7_pop_rate

#This was really interesting to me, because I expected a much higher percentage of Upper-Management to be paid over $50K a
#year.  This is probably low because not every CEO is a CEO of a huge company.  You could be a CEO of a really small company
#and potentially not make more than $50K/year.  The people providing Other-service as their occupation have the lowest chance
#of making more than $50K a year followed closely by manual laborers which is as expected.
# Out:
# Averages based on Occupation
#
# Occupation
# Manual-Labor          679
# Military              211
# Other-service         714
# Sales                 970
# Specialty-Service    2997
# Upper-Management     1937
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Occupation
# Manual-Labor         4527
# Military              653
# Other-service        8426
# Sales                3584
# Specialty-Service    8980
# Upper-Management     3992
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Occupation
# Manual-Labor         0.149989
# Military             0.323124
# Other-service        0.084738
# Sales                0.270647
# Specialty-Service    0.333742
# Upper-Management     0.485220
# Name: Is_Grtr_50, dtype: float64
#
# Compared to Average with Final Weight Accounted For
# Occupation
# Manual-Labor         122893686
# Military              42779392
# Other-service        133187926
# Sales                185515577
# Specialty-Service    571530453
# ...

# %%
#Now we will compare the odds of making $50K/year to your Work-Class
df_grouped8 = df.groupby(by='Work_Class')  
df_grouped8_pop_rate = df[df.Is_Grtr_50==1].groupby(by='Work_Class').Final_Weight.sum() / df_grouped8.Final_Weight.sum()

print "Averages based on Work Class"
print
print df_grouped8.Is_Grtr_50.sum()
print '------------------------'
print df_grouped8.Is_Grtr_50.count()
print '------------------------'
print df_grouped8.Is_Grtr_50.sum() / df_grouped8.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by='Work_Class').Final_Weight.sum()
print '------------------------'
print df_grouped8.Final_Weight.sum()
print '------------------------'
print df_grouped8_pop_rate

#As you can see the people who are self-employed have the highest chance of making more than $50K followed by Governement 
#Workers
# Out:
# Averages based on Work Class
#
# Work_Class
# Government-Worker    1318
# Not-Paid                0
# Private              4876
# Self-Employed        1314
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Work_Class
# Government-Worker     4289
# Not-Paid                14
# Private              22286
# Self-Employed         3573
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Work_Class
# Government-Worker    0.307298
# Not-Paid             0.000000
# Private              0.218792
# Self-Employed        0.367758
# Name: Is_Grtr_50, dtype: float64
#
# Compared to Average with Final Weight Accounted For
# Work_Class
# Government-Worker    249806977
# Private              922352518
# Self-Employed        240470421
# Name: Final_Weight, dtype: float64
# ------------------------
# Work_Class
# Government-Worker     800500641
# Not-Paid                2439745
# Private              4294957603
# Self-Employed         626663630
# ...

# %%
#Now we will combine the last two groupings (Occupation and Work Class) to see how they affect your odds of making more than
# $50K a year together
df_grouped9 = df.groupby(by=['Occupation','Work_Class'])  
df_grouped9_pop_rate = df[df.Is_Grtr_50==1].groupby(by=['Occupation','Work_Class']).Final_Weight.sum() / df_grouped9.Final_Weight.sum()


print "Averages based on Occupation and Work Class"
print
print df_grouped9.Is_Grtr_50.sum()
print '------------------------'
print df_grouped9.Is_Grtr_50.count()
print '------------------------'
print df_grouped9.Is_Grtr_50.sum() / df_grouped9.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by=['Occupation','Work_Class']).Final_Weight.sum()
print '------------------------'
print df_grouped9.Final_Weight.sum()
print '------------------------'
print df_grouped9_pop_rate

#As you can see from below the group with the highest chances of making more than $50K a year are the self-emloyed people 
#that provide some sort of professional specialty.  There are some fields with NaN in them and that is because they are not
#existent in the sample (meaning there are no unpaid manual laborers for example).  This grouping won't be 
#displayed in a bar graph as there are so many groups.
# Out:
# Averages based on Occupation and Work Class
#
# Occupation         Work_Class
# Manual-Labor       Government-Worker      42
#                    Not-Paid                0
#                    Private               506
#                    Self-Employed         131
# Military           Government-Worker     179
#                    Private                29
#                    Self-Employed           3
# Other-service      Government-Worker     189
#                    Not-Paid                0
#                    Private               480
#                    Self-Employed          45
# Sales              Government-Worker      11
#                    Private               677
#                    Self-Employed         282
# Specialty-Service  Government-Worker     624
#                    Not-Paid                0
#                    Private              1907
#                    Self-Employed         466
# Upper-Management   Government-Worker     273
# ...

# %%
#The next grouping will compare a records age range to their odds of making more than $50K a year.
df_grouped10 = df.groupby(by='Age_Range')  
df_grouped10_pop_rate = df[df.Is_Grtr_50==1].groupby(by='Age_Range').Final_Weight.sum() / df_grouped10.Final_Weight.sum()


print "Averages based on Age Range"
print
print df_grouped10.Is_Grtr_50.sum()
print '------------------------'
print df_grouped10.Is_Grtr_50.count()
print '------------------------'
print df_grouped10.Is_Grtr_50.sum() / df_grouped10.Is_Grtr_50.count()
print
print "Compared to Average with Final Weight Accounted For"
print df[df.Is_Grtr_50==1].groupby(by='Age_Range').Final_Weight.sum()
print '------------------------'
print df_grouped10.Final_Weight.sum()
print '------------------------'
print df_grouped10_pop_rate

#This was an interesting grouping because it shows how small your odds are of making more than $50K a year if you are 30 years
#or younger.  It also indicates that once you are 60 or older, the odds of you making greater than $50K a year significantly 
#drops off.
# Out:
# Averages based on Age Range
#
# Age_Range
# Early Adulthood     661
# Adult              6395
# Senior              452
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Age_Range
# Early Adulthood     9597
# Adult              18759
# Senior              1806
# Name: Is_Grtr_50, dtype: int64
# ------------------------
# Age_Range
# Early Adulthood    0.068876
# Adult              0.340903
# Senior             0.250277
# Name: Is_Grtr_50, dtype: float64
#
# Compared to Average with Final Weight Accounted For
# Age_Range
# Early Adulthood     129235870
# Adult              1205198045
# Senior               78196001
# Name: Final_Weight, dtype: float64
# ------------------------
# Age_Range
# Early Adulthood    1904286537
# Adult              3506588447
# Senior              313686635
# Name: Final_Weight, dtype: float64
# ------------------------
# Age_Range
# Early Adulthood    0.067866
# Adult              0.343695
# Senior             0.249281
# ...

# %%
#Now that we have some interesting groupings let's do some graph visualizations

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

#I chose bar graphs for most of these groupings as it is
#an easy way to view the averages across the different values
#in a category.  I made them horizontal so that when you are reading the groupings they are on the y-axis making it so you can 
#read normal words as opposed to sideways words.  I left off grouping 6 and 9 because they had so many groups it was difficult
#to visualize it well in a bar graph.

plot_bar_group1 = df_grouped1_pop_rate.plot(kind='barh',title='Average Making >$50K by Marital Status')
#As you can see, the married group by far has the highest odds of making more than $50K a year.

# %%
plot_bar_group3 = df_grouped3_pop_rate.plot(kind='barh',title='Average Making >$50K by Education')
#This is as expected, because as your level of education increases, so would the odds of you making more than $50K a year.

# %%
plot_bar_group5 = df_grouped5_pop_rate.plot(kind='barh',title='Average Making >$50K by Race')
#This shows that the group with the highest average above $50K is Asian followed by White.  Interestingly, you can also see
#that no race had an average of greater than 30%.  This signifies that no Race in particular was really highly paid, and that
#Race alone isn't a strong indicator of whether or not you will be paid more than $50K/year.  Ideally, all of these values
#would be equal, because this would imply that your race doesn't affect your odds of making more than $50k/year.
#Unfortunately, this indicates that your race does affect your odds.

# %%
plot_bar_group7 = df_grouped7_pop_rate.plot(kind='barh',title='Average Making >$50K by Occupation')
#Here it is interesting to see how less than half of Upper Management was making more than $50k a year.  It is also good to
#note that our Armed-Forces had the third highest average of people making more than $50K a year.

# %%
plot_bar_group8 = df_grouped8_pop_rate.plot(kind='barh',title='Average Making >$50K by Work Class')
#This shows how your odds of making more than $50K a year is higher if you are self employed vs. if you are working for the
#government.

# %%
plot_bar_group10 = df_grouped10_pop_rate.plot(kind='barh',title='Average Making >$50K by Age')
#As discussed above, the odds of making more than $50K decrease when you turn 60 and increase when you turn 30.

# %%
#Next we'll do some cross-tabulation to get another set of numbers for analysis

greater_than_50_1 = pd.crosstab([df['Is_Male'],df['Age_Range']], df.Is_Grtr_50.astype(bool))
print greater_than_50_1
greater_than_50_rate_1 = greater_than_50_1.div(greater_than_50_1.sum(1).astype(float),axis=0) # normalize the value
greater_than_50_rate_1.plot(kind='barh', stacked=True, color=['black','gold'],title='Age and Sex vs. Gross Income > $50k')

#This is a cool plot because you can visualize the odds across the board.  The fact that the graph is dominated by black shows
#how for no grouping of Age and Sex do you have a strong chance of making more than $50K a year, but your best chance is an
#Adult Male.  It also shows how for each age group males have an advantage.  The only group where women have an advantage is 
#an Adult Woman against an Early Adulthood Male.
# Out:
# Is_Grtr_50               False  True
# Is_Male Age_Range
# 0       Adult             4519    917
#         Early Adulthood   3617    149
#         Senior             534     46
# 1       Adult             7845   5478
#         Early Adulthood   5319    512
#         Senior             820    406

# %%
#Another group that the cross tabulation graph would be cool for would be Sex vs. Education
greater_than_50_2 = pd.crosstab([df['Is_Male'],df['Educ']], df.Is_Grtr_50.astype(bool))
print greater_than_50_2
greater_than_50_rate_2 = greater_than_50_2.div(greater_than_50_2.sum(1).astype(float),axis=0) # normalize the value
greater_than_50_rate_2.plot(kind='barh', stacked=True, color=['black','gold'],title='Education and Sex vs. Gross Income > $50k')

#I really liked this plot because it really shows some of the discrepancies between the sexes in relation to education and pay.
#  You can see that men have an advantage in every education level to the point where men with an education level 1 below women
# have a better chance of making $50k or more per year.  For example, a man with no High School Diploma has a better chance of
# making more than $50k a year than a woman with a High School Diploma!  A man with a Masters knows he has a better chance of 
# making more than $50k a year than a woman regardless of how much education she has completed.
# Out:
# Is_Grtr_50              False  True
# Is_Male Educ
# 0       College_Degree   1986    473
#         Doctorate          32     49
#         HS-grad          5215    398
#         Masters           337    172
#         No_HS_Diploma    1100     20
# 1       College_Degree   2783   2659
#         Doctorate          63    231
#         HS-grad          8350   2555
#         Masters           372    746
#         No_HS_Diploma    2416    205

# %%
#I did cross-tabulation for this grouping because it helps to see how certain groups have better averages than other groups.
greater_than_50_3 = pd.crosstab([df['Educ'],df['Is_US_Native']], df.Is_Grtr_50.astype(bool))
print greater_than_50_3
greater_than_50_rate_3 = greater_than_50_3.div(greater_than_50_3.sum(1).astype(float),axis=0) # normalize the value
greater_than_50_rate_3.plot(kind='barh', stacked=True, color=['black','gold'],title='Education and U.S. Native vs. Gross Income > $50k')

#This is a cool grouping, because you can very clearly see how being from the U.S. gives you a little boost regardless of your
#education level.  The odds of you making more than $50K a year increase across the board if you are from the U.S.
# Out:
# Is_Grtr_50                   False  True
# Educ           Is_US_Native
# College_Degree 0               397    226
#                1              4372   2906
# Doctorate      0                20     41
#                1                75    239
# HS-grad        0               904    145
#                1             12661   2808
# Masters        0                74     69
#                1               635    849
# No_HS_Diploma  0               750     32
#                1              2766    193

# %%
#Again there was some grouping in this data so I did a bar graph with cross-tabulation
greater_than_50_4 = pd.crosstab([df['Marital_Status'],df['Is_US_Native']], df.Is_Grtr_50.astype(bool))
print greater_than_50_4
greater_than_50_rate_4 = greater_than_50_4.div(greater_than_50_4.sum(1).astype(float),axis=0) # normalize the value
greater_than_50_rate_4.plot(kind='barh', stacked=True, color=['black','gold'],title='Marital Status and U.S. Native vs. Gross Income > $50k')
#From this graph you can see it is always better to be married, regardless of if you are from the U.S. originally or not.  It
#also indicates that the worst option is to not marry at all.  This is also an interesting graph, because unlike previous 
#groupings with whether or not you are a U.S. native, it is not an advantage always.  For instance, if you are a widower it is 
#better that you were not from the U.S.
# Out:
# Is_Grtr_50                   False  True
# Marital_Status Is_US_Native
# Divorced       0               306     29
#                1              4329    489
# Married        0               958    446
#                1              7058   5994
# Never-married  0               821     29
#                1              8435    441
# Widowed        0                60      9
#                1               687     71

# %%
#This last grouping was designed to see if there was a correlation between your sex and your occupation in relation to your
#odds of making more than $50k a year.
greater_than_50_5 = pd.crosstab([df['Is_Male'],df['Occupation']], df.Is_Grtr_50.astype(bool))
print greater_than_50_5
greater_than_50_rate_5 = greater_than_50_5.div(greater_than_50_5.sum(1).astype(float),axis=0) # normalize the value
greater_than_50_rate_5.plot(kind='barh', stacked=True, color=['black','gold'],title='Sex and Occupation vs. Gross Income > $50k')


#As expected, there is a strong relationship between your sex and occupation and your chances of making more than $50k a year.
#In particular women had an extremely low average of making more than $50k a year if there occupation was manual labor, sales,
#or other services.  A man who joins the military has a higher chance of making more than $50k a year than a women does
#regardless of her occupation.
# Out:
# Is_Grtr_50                 False  True
# Is_Male Occupation
# 0       Manual-Labor         667     31
#         Military              66     10
#         Other-service       4306    263
#         Sales               1160     88
#         Specialty-Service   1605    443
#         Upper-Management     866    277
# 1       Manual-Labor        3181    648
#         Military             376    201
#         Other-service       3406    451
#         Sales               1454    882
#         Specialty-Service   4378   2554
#         Upper-Management    1189   1660

# %%
#Next lets do some box plots to show the distributions of the data

#plot price of age and Hours/wk based on whether or not you make more than $50k a year.

# lets look at the boxplots separately
vars_to_plot_separate = [['Age','Hrs_Per_Week']]

for index, plot_vars in enumerate(vars_to_plot_separate):
    ax = df.boxplot(column=plot_vars, by='Is_Grtr_50',figsize=(15,7))
plt.show()

#These box plots help to look at the spread and distribution of the data.  You can notice that there is a lot of outliers 
#when looking at those who don't make more than $50k a year.  You can also visualize how for the most part (75%), people 
#who make more than $50k a work more than 40 hours a week.  You can also see how the people who don't make more then $50k
#a year are on average younger than those that do.

# %%
from pandas.tools.plotting import scatter_matrix

numeric_features = ['Age','Hrs_Per_Week','Is_Grtr_50']

df_numer = df[numeric_features]


numerical_categs = []
ax= scatter_matrix(df_numer,figsize=(15,10))

#This is an intersting graph that has two parts.  The diagonal from top left to bottom right is a normal histogram.  As you
#can see a majority of the data was taken from people who worked 30-40 hours a week and who were between the ages of 20 and 50.
#On the diagonal from bottom left to top right we have a scatter plot showing the values corresponding to each Age/Hours per
#Week.  We can also see that many more people made less than $50K a year vs. more than $50k a year.

# %%
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# %%
sns.set(style='darkgrid')
f, ax = plt.subplots(figsize=(15,15))

sns.corrplot(df,
             annot=True,
             sig_stars=True,
             diag_names=True,
             cmap=cmap,
             ax=ax)
f.tight_layout()

#This correlation plot is cool because not only does it give you an aesthetically pleasing view of correlated attributes,
#but it also runs statistical analysis on the attributes to determine which ones are correlated.  We can see that the 
#matches with an asterisk are significantly correlated.  We can see that whether or not someone is making more than $50k a 
#year is correlated to every other attribute (except Final Weight which makes sense).  This indicates that we would be able
#to generate a model that could predict whether or not someone was making more than $50k a year based on these attributes
#accurately.

# %%
#Now let's do a violin plot.

pal = sns.cubehelix_palette(40, rot=-.5, dark=.3)
sns.violinplot(df[['Age','Hrs_Per_Week']], color=pal, groupby=df.Is_Grtr_50.astype(bool))

#This violin plot shows the frequency of which someone was making more than $50k a year.  The wider the plot, the more 
#frequently that value occurred.  You can see that a majority of the people making more than $50k a year were between the ages
#of 30 and 50 and worked between approximately 35 and 45 hours a week.

# %%
#Factor Plot
sns.factorplot('Age_Range','Hrs_Per_Week','Is_Grtr_50',df,
               kind="box",
               palette="PRGn")
#This Factor plot is really useful to see the joint distribution of people who survived and who didn't based on the hours they
#worked per week, and how old they were.  We  can see that for every age group, the people who worked more had a much higher
#chance of making more than $50k a year.  We can also see that for the most part everyone worked the same amount of hours 
#that were making more than $50k a year.  However, of those that did not make $50k a year, they worked significantly less as 
#they got older.

# %%
#Pair Grid
sns.set(style="white")

#uses kernel density estimation
g = sns.PairGrid(df,diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot,lw=3)

#This pair grid is cool because it shows on the top right a scatter plot of each of the corresponding attributes based on
#their row and column value.  So we get a scatter plot of each combination of attribute.  In the upper left to bottom right
#diagonal we get a smoothed out histogram which allows us to easily visualize how the frequency of the data transitions as the
#values of the variable change.  In the bottom triangle we see the kernel density estimation which shows how the values are 
#clustered in relation to other attributes.  For example, all the attributes that are binomial and have either values 1 or 0
#will most likely have to clusters around 0 and 1.  The darker the rings, the higher the density of the points with those
#values.  For example there is a high density for the values between 30 and 50 for age and around 40 hours of work per week.

# %%
#Facet Grid

sns.set(style='darkgrid')
 
g= sns.FacetGrid(df, col="Age_Range", row="Is_Male", margin_titles=True)
g.map(plt.hist, "Is_Grtr_50", color="steelblue", lw=0)
mpld3.display()
#This is a cool way of comparing a couple different attributes in relation to whether or not they made more than $50k a year.
#You can see that for all age ranges the male has a higher chance of making more than $50k a year.  However, with this plot
#you can also see that there were a lot more men who didn't make more than $50k a year as well.
# Out:
# <style>
#
# </style>
#
# <div id="fig_el849446309897762825815806"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...
