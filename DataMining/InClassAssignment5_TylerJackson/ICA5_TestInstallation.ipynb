# %% [markdown]
# #In Class Assignment Five Test Installation
# In the in class assignment you will be asked to fill in python code and R code. Please make sure that this notebook can be run in its entirety before class.
#
# ________________________________________________________________________________________________________
#
# ##Running in the 'R' Ecosystem with magics

# %%
# getting things started
import time
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# You will need to have R installed, as well as Rpy2 and the arules library
from rpy2.robjects.packages import importr
from rpy2 import robjects as robj

# this way we can write r code by simply writing %R
# %load_ext rmagic
# %load_ext rpy2.ipython 
# this enables the %R extension to iPython (does not work outside of the iPython shell)

# these packages will need to be installed
# open R and run 
#     install.package(arules)
#     install.package(arulesViz)

arules = importr('arules') # same as importing in R with the "library" command
arules_viz = importr('arulesViz') # visualize the different rules
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %R load("titanic2.raw.rdata")
# %R rules <- apriori(titanic.raw,parameter = list(minlen=2, supp=0.05, conf=0.8))
# %R rules.sorted <- sort(rules, by="lift")
# %R inspect(rules.sorted, n=10)
# %R plot(rules.sorted, method="grouped")

# Make sure that the titanic data is in the same directory
print 'It worked!'
# Out:
# Parameter specification:
#  confidence minval smax arem  aval originalSupport support minlen maxlen target
#         0.8    0.1    1 none FALSE            TRUE    0.05      2     10  rules
#    ext
#  FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# apriori - find association rules with the apriori algorithm
# version 4.21 (2004.05.09)        (c) 1996-2004   Christian Borgelt
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[10 item(s), 2201 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [49 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
#    lhs               rhs               support confidence      lift
# 1  {Class=1st,
#     Sex=Female}   => {Survived=Yes} 0.06406179  0.9724138 3.0102430
# 2  {Class=1st,
#     Sex=Female,
#     Age=Adult}    => {Survived=Yes} 0.06360745  0.9722222 3.0096499
# 3  {Class=2nd,
#     Sex=Male,
#     Age=Adult}    => {Survived=No}  0.06996820  0.9166667 1.3540828
# 4  {Class=2nd,
#     Sex=Male}     => {Survived=No}  0.06996820  0.8603352 1.2708710
# 5  {Class=Crew,
#     Survived=No}  => {Sex=Male}     0.30440709  0.9955423 1.2658514
# 6  {Class=Crew,
#     Age=Adult,
#     Survived=No}  => {Sex=Male}     0.30440709  0.9955423 1.2658514
# 7  {Class=Crew}   => {Sex=Male}     0.39164016  0.9740113 1.2384742
# 8  {Class=Crew,
#     Age=Adult}    => {Sex=Male}     0.39164016  0.9740113 1.2384742
# 9  {Class=3rd,
#     Sex=Male,
#     Age=Adult}    => {Survived=No}  0.17582917  0.8376623 1.2373791
# 10 {Class=1st,
#     Survived=No}  => {Sex=Male}     0.05361199  0.9672131 1.2298302
# 11 {Class=1st,
#     Age=Adult,
#     Survived=No}  => {Sex=Male}     0.05361199  0.9672131 1.2298302
# 12 {Class=3rd,
#     Sex=Male}     => {Survived=No}  0.19173103  0.8274510 1.2222950
# 13 {Age=Adult,
#     Survived=No}  => {Sex=Male}     0.60381645  0.9242003 1.1751385
# 14 {Class=2nd,
#     Survived=No}  => {Sex=Male}     0.06996820  0.9221557 1.1725388
# 15 {Class=2nd,
#     Age=Adult,
#     Survived=No}  => {Sex=Male}     0.06996820  0.9221557 1.1725388
# 16 {Survived=No}  => {Sex=Male}     0.61971831  0.9154362 1.1639949
# 17 {Class=Crew,
#     Survived=Yes} => {Sex=Male}     0.08723308  0.9056604 1.1515647
# 18 {Class=Crew,
#     Age=Adult,
#     Survived=Yes} => {Sex=Male}     0.08723308  0.9056604 1.1515647
# 19 {Class=Crew}   => {Age=Adult}    0.40208996  1.0000000 1.0521033
# 20 {Class=2nd,
#     Survived=No}  => {Age=Adult}    0.07587460  1.0000000 1.0521033
# 21 {Class=1st,
#     Survived=No}  => {Age=Adult}    0.05542935  1.0000000 1.0521033
# 22 {Class=Crew,
#     Survived=Yes} => {Age=Adult}    0.09631985  1.0000000 1.0521033
# 23 {Class=Crew,
#     Survived=No}  => {Age=Adult}    0.30577010  1.0000000 1.0521033
# 24 {Class=Crew,
#     Sex=Male}     => {Age=Adult}    0.39164016  1.0000000 1.0521033
# 25 {Class=2nd,
#     Sex=Male,
#     Survived=No}  => {Age=Adult}    0.06996820  1.0000000 1.0521033
# 26 {Class=1st,
#     Sex=Male,
#     Survived=No}  => {Age=Adult}    0.05361199  1.0000000 1.0521033
# 27 {Class=Crew,
#     Sex=Male,
#     Survived=Yes} => {Age=Adult}    0.08723308  1.0000000 1.0521033
# 28 {Class=Crew,
#     Sex=Male,
#     Survived=No}  => {Age=Adult}    0.30440709  1.0000000 1.0521033
# 29 {Class=1st,
#     Sex=Female}   => {Age=Adult}    0.06542481  0.9931034 1.0448474
# 30 {Class=1st,
#     Sex=Female,
#     Survived=Yes} => {Age=Adult}    0.06360745  0.9929078 1.0446415
# 31 {Class=3rd,
#     Age=Adult,
#     Survived=No}  => {Sex=Male}     0.17582917  0.8130252 1.0337773
# 32 {Class=1st}    => {Age=Adult}    0.14493412  0.9815385 1.0326798
# 33 {Sex=Male,
#     Survived=No}  => {Age=Adult}    0.60381645  0.9743402 1.0251065
# 34 {Class=1st,
#     Sex=Male}     => {Age=Adult}    0.07950931  0.9722222 1.0228782
# 35 {Class=1st,
#     Survived=Yes} => {Age=Adult}    0.08950477  0.9704433 1.0210066
# 36 {Survived=No}  => {Age=Adult}    0.65333939  0.9651007 1.0153856
# 37 {Sex=Male}     => {Age=Adult}    0.75738301  0.9630272 1.0132040
# 38 {Class=2nd,
#     Sex=Male}     => {Age=Adult}    0.07632894  0.9385475 0.9874489
# 39 {Sex=Male,
#     Survived=Yes} => {Age=Adult}    0.15356656  0.9209809 0.9689670
# 40 {Survived=Yes} => {Age=Adult}    0.29713766  0.9198312 0.9677574
# 41 {Sex=Female,
#     Survived=Yes} => {Age=Adult}    0.14357110  0.9186047 0.9664669
# 42 {Class=3rd,
#     Sex=Male,
#     Survived=No}  => {Age=Adult}    0.17582917  0.9170616 0.9648435
# 43 {Class=2nd}    => {Age=Adult}    0.11858246  0.9157895 0.9635051
# 44 {Class=3rd,
#     Sex=Male}     => {Age=Adult}    0.20990459  0.9058824 0.9530818
# 45 {Sex=Female}   => {Age=Adult}    0.19309405  0.9042553 0.9513700
# 46 {Class=3rd,
#     Survived=No}  => {Age=Adult}    0.21626533  0.9015152 0.9484870
# 47 {Class=3rd}    => {Age=Adult}    0.28487051  0.8881020 0.9343750
# 48 {Class=3rd,
#     Survived=Yes} => {Age=Adult}    0.06860518  0.8483146 0.8925146
# 49 {Class=3rd,
#     Sex=Female}   => {Age=Adult}    0.07496592  0.8418367 0.8856992
# It worked!

# %% [markdown]
# If run properly you should see a graph above showing grouped plots of the rules. That's it. You are done!!
